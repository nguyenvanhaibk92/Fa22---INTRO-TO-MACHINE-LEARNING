# %% [markdown]
# ## <h1><center>Course: Introduction to Machine Learning</center></h1>
# ## <h1><center>Assigment 5</center></h1>
# ### <h1><center>Important NOTE: In order to get full grades, for every question, you need to provide the details of your work on how to get to a solution or the end of the proof</center></h1>
# #### <h1><center>Instructor: Tan Bui-Thanh</center></h1>
# #### <h1><center>TA: Hai Nguyen</center></h1>
# ##### <h1><center>Due day: , 2022 </center></h1>
# #### All solutions must be in one pdf file except codes.

# %% [markdown]
# $\newcommand{\LRp}[1]{\left( #1 \right)}$
# $\newcommand{\LRs}[1]{\left[ #1 \right]}$
# $\newcommand{\LRa}[1]{\left< #1 \right>}$
# $\newcommand{\LRc}[1]{\left\{ #1 \right\}}$
# $\newcommand{\prob}[1]{P\LRs{#1}}$
# $\newcommand{\Dis}[2]{\mathcal{N}\LRp{#1, #2}}$
# $\newcommand{\t}{\theta}$
# $\newcommand{\d}{\mathcal{D}}$
# $\newcommand{\s}{\mathcal{S}}$
# $\newcommand{\yi}{y^{(i)}}$
# $\newcommand{\xid}{x^{(i)}}$
# $\newcommand{\grad}[2]{\nabla_{#1}\LRp{#2}}$

# %% [markdown]
# ## Question 1:
#
# In seperable problems, we can achieve the optimal $\lambda$ by solving dual optimization problems. Assume that our marginal model for a data point is
#
# $$\gamma^{(i)} = y^{(i)} \LRp{\t^T \phi(x^{(i)}) + \t_0}$$
#
# What is formula for $\t^*$. And, show that
#
# $$\t_0^* = \frac{1}{N_\s} \sum_{i \in \s} \LRp{\yi - \sum_{j \in \s} \lambda_j y^{(j)}\LRp{\phi(x)^{(i)}}^T \phi(x)^{(j)} }, $$
#
# where $\s$ denotes the set of all support vectors. (which is stable version to compute $\t_0^*$).

# %% [markdown]
# ## Question 2: (I am not sure about this question)
#
# Given the model
#
# $$y = \t^T \phi(x) + \epsilon .$$
#
# Derive the kernel form of Ridge Regression problem.

# %% [markdown]
# ## Question 3:
#
# Show that Radial Basis Function (RBF; sometimes called Gaussian) kernel
# $$K(x,z) = \exp \left(-\frac{||x - z||^2}{2\sigma^2}\right),$$
#
# is a  Mercer kernel.

# %% [markdown]
# ## Question 4: (decision tree for linear regression)
#
# In the lecture note, we have performed decision tree for classification on Iris data set. We have learned that if we use a large depth the decision tree will overfit the data, leading to high variance. Bagging is a technique to reduce high variance.
#
# Question:
# 1. Similarly to the logistic regression problem in the lecture note 12, you can use the given code below, and then perform bagging method (with max_depth = 5) to reduce the overfitting. (You should test a few cases: (different number of models, different random small subsets). For examaple, in the lecture notes 300 models and 40 samples for one subset)
#
# 2. Discuss the result.

# %%
# Import the necessary modules and libraries
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue", label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
